# %%
from cmath import sqrt
def quadform_keyword(a=1,b=1,c=1):
    x_1=(-b+sqrt(b**2-4*a*c))/(2*a)
    x_2=(-b-sqrt(b**2-4*a*c))/(2*a)
    return x_1,x_2
    
print(quadform_keyword(c=1,b=2,a=3))
# Out:
# ((-0.3333333333333333+0.47140452079103173j), (-0.3333333333333333-0.47140452079103173j))

# %%
from cmath import sqrt
def quadform_keyword(a=1,b=1,c=1):
    x_1=(-b+sqrt(b**2-4*a*c))/(2*a)
    x_2=(-b-sqrt(b**2-4*a*c))/(2*a)
    return x_1,x_2
    
print(quadform_keyword(c=1,b=2,a=3))
print(quadform_keyword(3,2,1))
# Out:
# ((-0.3333333333333333+0.47140452079103173j), (-0.3333333333333333-0.47140452079103173j))
# ((-0.3333333333333333+0.47140452079103173j), (-0.3333333333333333-0.47140452079103173j))

# %%
'''variable keyword parameters:
def quadform_varKeyword(**v):

variable position parameters:need to have same order as used in function
    def quadform_varpos(*v): #the star means we do not know how many  am going to receive

read about dictionaries
'''


def myFunc(A ,B = 10, *C, **D):
    print("A", A, "B = ", B, "C = ", C, "D =", D)
    return

myFunc(A=5, B=11, C=(10,20,25), D={'y':66, 'x':99})
# Out:
# A 5 B =  11 C =  () D = {'C': (10, 20, 25), 'D': {'y': 66, 'x': 99}}

# %%
def funnyFunc(q, a):
    print("Q: ", q)
    print("A: ", a)

funnyFunc("what is the weather tomorrow?",\
    "Sunny with a chance of sun.") #| add a new line
# Out:
# Q:  what is the weather tomorrow?
# A:  Sunny with a chance of sun.

# %%
#Lab 4
from math import pi

def normal_probDesityFunc(sigma)
#sigma is standard deviation = 1,

y = 1 / sigma *sqrt(2*pi)

print(y)
# Out:
#   File "<ipython-input-5-10001d8383ef>", line 4
#     def normal_probDesityFunc(sigma)
#                                     ^
# SyntaxError: invalid syntax

# %%
#Lab 4
from math import pi

def normal_probDesityFunc(sigma)
#sigma is standard deviation = 1, mean = 0

    y = 1 / sigma *sqrt(2*pi)

    print(y)
    return

normal_probDesityFunc(10)
# Out:
#   File "<ipython-input-6-9e887c8442af>", line 4
#     def normal_probDesityFunc(sigma)
#                                     ^
# SyntaxError: invalid syntax

# %%
#Lab 4
from math import pi

def normal_probDesityFunc(sigma):
#sigma is standard deviation = 1, mean = 0

    y = 1 / sigma *sqrt(2*pi)

    print(y)
    return

normal_probDesityFunc(10)
# Out:
# (0.25066282746310004+0j)

# %%
#Lab 4
from math import pi, exp

def normal_probDesityFunc(sigma):
#sigma is standard deviation = 1, mean = 0

    y = 1 / sigma *sqrt(2*pi)

    expon = exp(-(.5)*(x - m/sigma))

    print(y)
    return

normal_probDesityFunc(10, 1, 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-2cb7a00075e0> in <module>
#      12     return
#      13
# ---> 14 normal_probDesityFunc(10, 1, 0)
#      15
#
# TypeError: normal_probDesityFunc() takes 1 positional argument but 3 were given

# %%
#Lab 4
from math import pi, exp

def normal_probDesityFunc(x, mu, sigma,):
#sigma is standard deviation = 1, mean = 0

    y = 1 / sigma *sqrt(2*pi)

    expon = exp(-(.5)*(x - mu/sigma))

    print(y)
    return

normal_probDesityFunc(10, 1, 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-cf6e2bf24cba> in <module>
#      12     return
#      13
# ---> 14 normal_probDesityFunc(10, 1, 0)
#      15
#
# <ipython-input-9-cf6e2bf24cba> in normal_probDesityFunc(x, mu, sigma)
#       5 #sigma is standard deviation = 1, mean = 0
#       6
# ----> 7     y = 1 / sigma *sqrt(2*pi)
#       8
#       9     expon = exp(-(.5)*(x - mu/sigma))
#
# ZeroDivisionError: division by zero

# %%
#Lab 4
from math import pi, exp

def normal_probDesityFunc(x, mu, sigma,):
#sigma is standard deviation = 1, mean = 0

    y = 1 / sigma *sqrt(2*pi)

    expon = exp(-(.5)*(x - mu/sigma))

    junto = y*expon
    print(junto)
    return

normal_probDesityFunc(0, 1, 10) #asi como se dan los parameters asi aqui en ordern tmb
# Out:
# (0.26351458544784734+0j)

# %%
#Lab 4
from math import pi, exp

def normal_probDesityFunc(x, mu, sigma,):
#sigma is standard deviation = 1, mean = 0

    y = 1 / sigma *sqrt(2*pi)

    expon = exp(-(.5)*(x - mu/sigma))

    junto = y*expon
    print(junto)
    return

normal_probDesityFunc(0, 0, 1) #asi como se dan los parameters asi aqui en ordern tmb
# Out:
# (2.5066282746310002+0j)

# %%
#Lab 4
from math import pi, exp

def normal_probDesityFunc(x, mu, sigma,):
#sigma is standard deviation = 1, mean = 0

    y = 1 / sigma *sqrt(2*pi)

    expon = exp(-(.5)*(x - mu/sigma))

    junto = y*expon
    print(junto)
    return

normal_probDesityFunc(2, 0, 1) #asi como se dan los parameters asi aqui en ordern tmb
# Out:
# (0.9221370088957891+0j)

# %%
#Lab 4
from math import pi, exp

def normal_probDesityFunc(x, mu, sigma,):
#sigma is standard deviation = 1, mean = 0

    y = 1 / sigma *sqrt(2*pi)

    expon = exp(-(.5)*(x - mu/sigma)**2)

    junto = y*expon
    print(junto)
    return

normal_probDesityFunc(2, 0, 1) #asi como se dan los parameters asi aqui en ordern tmb
# Out:
# (0.33923524751608825+0j)

# %%
#Lab 4
from math import pi, exp

def normal_probDesityFunc(x, mu, sigma):
#sigma is standard deviation = 1, mean = 0

    y = 1 / sigma *sqrt(2*pi)

    expon = exp(-(.5)*(x - mu/sigma)**2)

    junto = y*expon
    print(junto)
    return

normal_probDesityFunc(2, 0, 1) #asi como se dan los parameters asi aqui en ordern tmb
# Out:
# (0.33923524751608825+0j)

# %%
#Lab 4
import matplotlib.pyplot as plt
from math import pi, exp

def normal_probDesityFunc(x, mu, sigma):
#sigma is standard deviation = 1, mean = 0

    y = 1 / sigma *sqrt(2*pi)

    expon = exp(-(.5)*(x - mu/sigma)**2)

    junto = y*expon
    print(junto)
    # Create the plot
    plt.plot(x,y)

    # Show the plot
    plt.show()
    return

normal_probDesityFunc(2, 0, 1) #asi como se dan los parameters asi aqui en ordern tmb

# Create the plot
plt.plot(x,y)

# Show the plot
plt.show()
# Out:
# (0.33923524751608825+0j)
# C:\Users\anayeli\Anaconda3\lib\site-packages\numpy\core\numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5812d3714e9c> in <module>
#      22
#      23 # Create the plot
# ---> 24 plt.plot(x,y)
#      25
#      26 # Show the plot
#
# NameError: name 'x' is not defined

# %%
#Lab 4
import matplotlib.pyplot as plt
from math import pi, exp

def normal_probDesityFunc(x, mu, sigma):
#sigma is standard deviation = 1, mean = 0

    y = 1 / sigma *sqrt(2*pi)

    expon = exp(-(.5)*(x - mu/sigma)**2)

    junto = y*expon
    print(junto)
    # Create the plot
    plt.plot(junto)

    # Show the plot
    plt.show()
    return

normal_probDesityFunc(2, 0, 1) #asi como se dan los parameters asi aqui en ordern tmb

# Create the plot
plt.plot(x,y)

# Show the plot
plt.show()
# Out:
# (0.33923524751608825+0j)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-5642a90efdd9> in <module>
#      22
#      23 # Create the plot
# ---> 24 plt.plot(x,y)
#      25
#      26 # Show the plot
#
# NameError: name 'x' is not defined

# %%
#Lab 4
import matplotlib.pyplot as plt
from math import pi, exp

def normal_probDesityFunc(x, mu, sigma):
#sigma is standard deviation = 1, mean = 0

    y = 1 / sigma *sqrt(2*pi)

    expon = exp(-(.5)*(x - mu/sigma)**2)

    junto = y*expon
    print(junto)
    # Create the plot
    plt.plot(junto)

    # Show the plot
    plt.show()
    return

normal_probDesityFunc(2, 0, 1) #asi como se dan los parameters asi aqui en ordern tmb
# Out:
# (0.33923524751608825+0j)

# %%
#Lab 4
import matplotlib.pyplot as plt
from math import pi, exp

def normal_probDesityFunc(x, mu, sigma):
#sigma is standard deviation = 1, mean = 0

    y = 1 / sigma *sqrt(2*pi)

    expon = exp(-(.5)*((x - mu)/sigma)**2)

    junto = y*expon
    print(junto)
    # Create the plot
    plt.plot(junto)

    # Show the plot
    plt.show()
    return

normal_probDesityFunc(2, 0, 1) #asi como se dan los parameters asi aqui en ordern tmb
# Out:
# (0.33923524751608825+0j)

# %%
#Lab 4
import matplotlib.pyplot as plt
from math import pi, exp

def normal_probDesityFunc(x, mu, sigma):
#sigma is standard deviation = 1, mean = 0

    y = 1 / sigma *sqrt(2*pi)

    expon = exp(-(.5)*((x - mu)/sigma)**2)

    junto = y*expon
    print(junto)
    # Create the plot
    plt.plot(junto)

    # Show the plot
    plt.show()
    return

normal_probDesityFunc(0, 0, 1) #asi como se dan los parameters asi aqui en ordern tmb
# Out:
# (2.5066282746310002+0j)

# %%
#Lab 4
import matplotlib.pyplot as plt
from math import pi, exp

def normal_probDesityFunc(x, mu, sigma):
#sigma is standard deviation = 1, mean = 0

    y = 1 / (sigma *sqrt(2*pi) )

    expon = exp(-(.5)*((x - mu)/sigma)**2)

    junto = y*expon
    print(junto)
    # Create the plot
    plt.plot(junto)

    # Show the plot
    plt.show()
    return

normal_probDesityFunc(0, 0, 1) #asi como se dan los parameters asi aqui en ordern tmb
# Out:
# (0.3989422804014327+0j)

# %%
# Import our modules that we are using
import matplotlib.pyplot as plt
import numpy as np

# Create the vectors X and Y
x = np.array(range(100))
y = x ** 2

# Create the plot
plt.plot(x,y)

# Show the plot
plt.show()

# %%
#Lab 4 part 3
''' use linspace
'''
mu = 0
sigma = 1
a = -3
b = 3.0
n = 10
from numpy import linspace


from math import pi, exp


x = linspace(a, b, n)#this will set up x as a list

for y in x:

    z = nomal(y, mu, sigma)
    print(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-b4c7f077431c> in <module>
#      17 for y in x:
#      18
# ---> 19     z = nomal(y, mu, sigma)
#      20     print(z)
#
# NameError: name 'nomal' is not defined

# %%
#Lab 4 part 3
''' use linspace
'''
mu = 0
sigma = 1
a = -3
b = 3.0
n = 10
from numpy import linspace


from math import pi, exp

def normal(x, mu, sigma):
#sigma is standard deviation = 1, mean = 0

    y = 1 / (sigma *sqrt(2*pi) )
    expon = exp(-(.5)*((x - mu)/sigma)**2)

    junto = y*expon
    print(junto)
    return

x = linspace(a, b, n)#this will set up x as a list

for y in x:

    z = normal(y, mu, sigma)
    print(z)
# Out:
# (0.0044318484119380075+0j)
# None
# (0.026221889093709483+0j)
# None
# (0.09947713879274868+0j)
# None
# (0.24197072451914337+0j)
# None
# (0.37738322769299315+0j)
# None
# (0.3773832276929932+0j)
# None
# (0.24197072451914337+0j)
# None
# (0.09947713879274879+0j)
# None
# (0.026221889093709518+0j)
# None
# (0.0044318484119380075+0j)
# None

# %%
#Lab 4 part 3
''' use linspace
'''
mu = 0
sigma = 1
a = -3
b = 3.0
n = 10
from numpy import linspace


from math import pi, exp

def normal(x, mu, sigma):
#sigma is standard deviation = 1, mean = 0

    y = 1 / (sigma *sqrt(2*pi) )
    expon = exp(-(.5)*((x - mu)/sigma)**2)

    junto = y*expon
    print(junto)
    return junto

x = linspace(a, b, n)#this will set up x as a list

for y in x:

    z = normal(y, mu, sigma)
    print(z)
# Out:
# (0.0044318484119380075+0j)
# (0.0044318484119380075+0j)
# (0.026221889093709483+0j)
# (0.026221889093709483+0j)
# (0.09947713879274868+0j)
# (0.09947713879274868+0j)
# (0.24197072451914337+0j)
# (0.24197072451914337+0j)
# (0.37738322769299315+0j)
# (0.37738322769299315+0j)
# (0.3773832276929932+0j)
# (0.3773832276929932+0j)
# (0.24197072451914337+0j)
# (0.24197072451914337+0j)
# (0.09947713879274879+0j)
# (0.09947713879274879+0j)
# (0.026221889093709518+0j)
# (0.026221889093709518+0j)
# (0.0044318484119380075+0j)
# (0.0044318484119380075+0j)

# %%
#Lab 4 part 3
''' use linspace
'''
mu = 0
sigma = 1
a = -3
b = 3.0
n = 10
from numpy import linspace


from math import pi, exp

def normal(x, mu, sigma):
#sigma is standard deviation = 1, mean = 0

    y = 1 / (sigma *sqrt(2*pi) )
    expon = exp(-(.5)*((x - mu)/sigma)**2)

    junto = y*expon
    #print(junto)
    return junto

x = linspace(a, b, n)#this will set up x as a list

for y in x:

    z = normal(y, mu, sigma)
    print(z)
# Out:
# (0.0044318484119380075+0j)
# (0.026221889093709483+0j)
# (0.09947713879274868+0j)
# (0.24197072451914337+0j)
# (0.37738322769299315+0j)
# (0.3773832276929932+0j)
# (0.24197072451914337+0j)
# (0.09947713879274879+0j)
# (0.026221889093709518+0j)
# (0.0044318484119380075+0j)

# %%
#Lab 4 part 3
''' use linspace
'''
mu = 0
sigma = 1
a = -3
b = 3.0
n = 10
from numpy import linspace


from math import pi, exp, sqrt

def normal(x, mu, sigma):
#sigma is standard deviation = 1, mean = 0

    y = 1 / (sigma *sqrt(2*pi) )
    expon = exp(-(.5)*((x - mu)/sigma)**2)

    junto = y*expon
    #print(junto)
    return junto

x = linspace(a, b, n)#this will set up x as a list

for y in x:

    z = normal(y, mu, sigma)
    print(z)
# Out:
# 0.0044318484119380075
# 0.026221889093709483
# 0.09947713879274868
# 0.24197072451914337
# 0.37738322769299315
# 0.3773832276929932
# 0.24197072451914337
# 0.09947713879274879
# 0.026221889093709518
# 0.0044318484119380075
